# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/My Drive/Celebrity/image.jpg')

# %%
img.shape
# Out:
# (1318, 678, 3)

# %%
plt.imshow(img)
